# %% [raw]
# ----1. What are data structures, and why are they important?
# Data structures are ways to organize and store data so it can be used efficiently.
#
# Common Types:
# Array – fixed-size list
# Linked List – items linked in sequence
# Stack/Queue – last-in-first-out / first-in-first-out
# Tree/Graph – hierarchical or networked data
# Hash Map – key-value pairs for fast lookup
#
#
# ----2. Explain the difference between mutable and immutable data types with examples?
# Mutable data types can be changed after creation (modified in place).
# Immutable data types cannot be changed once created; any modification creates a new object.
#
# Mutable Data Types
# list
# dict
# set
#
# Immutable Data Types
# int
# float
# str
# tuple
#
#
# ----3. Main differences between lists and tuples
# Lists are mutable (can be changed), tuples are immutable (can’t be changed).
#
# Lists use [], tuples use ().
#
# Tuples are faster and use less memory than lists.
#
#
# ----4. How dictionaries store data
# Dictionaries store data as key-value pairs.
#
# Internally, they use a hash table to quickly map keys to values.
#
#
# ----5. Why use a set instead of a list
# Sets automatically remove duplicates.
#
# Sets provide faster lookup (in operations) than lists.
#
#
# ----6. What is a string in Python, and how is it different from a list
# A string is an immutable sequence of characters.
#
# A list is a mutable sequence of items, which can be of any type.
#
#
# ----7. How tuples ensure data integrity
# Tuples are immutable, so their contents can’t be changed after creation, making them useful for fixed data or as keys in dictionaries.
#
#
# ----8. What is a hash table, and how does it relate to dictionaries in Python
# A hash table is a data structure that maps keys to values using a hash function.
#
# Python dictionaries are implemented using hash tables.
#
#
# ----9. Can lists contain different data types in Python
# Yes, Python lists can hold multiple data types (e.g., ["hello", 3.14, True]).
#
#
# ----10. Why strings are immutable in Python
# Strings are immutable to ensure security, thread safety, and to enable internal optimizations like string interning.
#
#
# ----11. Advantages of dictionaries over lists
# Faster lookups by key.
#
# Ideal for mapping relationships (e.g., student names to grades).
#
# Avoids manual searching through indexes.
#
#
# ----12. When to use a tuple over a list
# When you want to ensure data cannot be changed.
#
# Example: coordinates (x, y), days of the week, dictionary keys.
#
#
# ----13. How sets handle duplicate values
# Sets automatically eliminate duplicate values. Each element must be unique.
#
#
# ----14. How the in keyword works for lists vs dictionaries
# In lists: checks if a value exists.
#
# In dictionaries: checks if a key exists (not the value).
#
#
# ----15. Can you modify elements of a tuple?
# No. Tuples are immutable, so you cannot modify, add, or remove items after creation.
#
#
# ----16. What is a nested dictionary? Example:
# A dictionary inside another dictionary.
#
# python
# Copy
# Edit
# student = {
#   "name": "Alex",
#   "grades": {
#     "math": 90,
#     "science": 85
#   }
# }
#
#
# ----17. Time complexity of accessing elements in a dictionary
# Average case: O(1) – constant time access using a key.
#
#
# ----18. When lists are preferred over dictionaries
# When order matters or when storing collections without key-value pairs.
#
# When iterating in sequence is needed.
#
#
# ----19. Why dictionaries are considered unordered (pre-3.7)
# Before Python 3.7, dictionaries didn’t preserve insertion order.
#
# Now they do preserve order, but they are still accessed by key, not by position.
#
#
# ----20. Difference between list and dictionary in data retrieval
# List: access by index (e.g., my_list[0]).
#
# Dictionary: access by key (e.g., my_dict["name"]), which is usually faster

# %% [raw]
# ----1. Write a code to create a string with your name and print it.
# name = "Mayur"
# print(name)
#
# ---2. Write a code to find the length of the string "Hello World".
# text = "Hello World"
# print(len(text))
#
# ----3. Write a code to slice the first 3 characters from the string "Python Programming".
# text = "Python Programming"
# print(text[:3])
#
# ----4. Write a code to convert the string "hello" to uppercase.
# text = "hello"
# print(text.upper())
#
# ----5. Write a code to replace the word "apple" with "orange" in the string "I like apple".
# text = "I like apple"
# print(text.replace("apple", "orange"))
#
# ----6. Write a code to create a list with numbers 1 to 5 and print it.
# numbers = [1, 2, 3, 4, 5]
# print(numbers)
#
# ----7. Write a code to append the number 10 to the list [1, 2, 3, 4].
# numbers = [1, 2, 3, 4]
# numbers.append(10)
# print(numbers)
#
# ---8. Write a code to remove the number 3 from the list [1, 2, 3, 4, 5].
# numbers = [1, 2, 3, 4, 5]
# numbers.remove(3)
# print(numbers)
#
# ----9. Write a code to access the second element in the list ['a', 'b', 'c', 'd'].
# letters = ['a', 'b', 'c', 'd']
# print(letters[1])
#
# ----10. Write a code to reverse the list [10, 20, 30, 40, 50].
# numbers = [10, 20, 30, 40, 50]
# numbers.reverse()
# print(numbers)
